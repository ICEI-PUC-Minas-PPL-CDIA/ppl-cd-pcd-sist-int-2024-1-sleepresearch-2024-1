# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importando as tabelas:

# %%
stress_data = pd.read_csv("..\\assets\\data\\Student Stress Factors.csv")

# %%
performance_data = pd.read_csv("..\\assets\\data\\Student_Performance.csv")

# %% [markdown]
# ### Info das tabelas

# %%
stress_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sleep Quality                        520 non-null    int64
#  1   suffer headaches                     520 non-null    int64
#  2   academic performance                 520 non-null    int64
#  3   study load                           520 non-null    int64
#  4   practice extracurricular activities  520 non-null    int64
#  5   stress levels                        520 non-null    int64
# dtypes: int64(6)
# memory usage: 24.5 KB

# %%
performance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
stress_data.describe()
# Out:
#        Sleep Quality  suffer headaches  academic performance  study load  \
# count     520.000000        520.000000            520.000000  520.000000
# mean        3.125000          2.182692              3.326923    2.750000
# std         1.099023          1.247459              1.061158    1.372381
# min         1.000000          1.000000              1.000000    1.000000
# 25%         2.000000          1.000000              3.000000    2.000000
# 50%         3.000000          2.000000              3.000000    2.500000
# 75%         4.000000          3.000000              4.000000    4.000000
# max         5.000000          5.000000              5.000000    5.000000
#
#        practice extracurricular activities  stress levels
# count                           520.000000     520.000000
# mean                              2.682692       2.875000
# std                               1.470745       1.357825
# min                               1.000000       1.000000
# ...

# %%
performance_data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
g1 = sns.PairGrid(performance_data)
g1.map_diag(plt.hist)
g1.map_upper(plt.scatter)
g1.map_lower(sns.lineplot)

# %% [markdown]
# ### Troca de tipos

# %% [markdown]
# #### Performance Index

# %%
performance_data['Performance Index'] = performance_data['Performance Index'].astype('int64')

# %%
performance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 468.9+ KB

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
performance_data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %% [markdown]
# #### Extracurricular Activities

# %%
performance_data.loc[performance_data['Extracurricular Activities'] == 'Yes', 'Extracurricular Activities'] = 1

# %%
performance_data.loc[performance_data['Extracurricular Activities'] == 'No', 'Extracurricular Activities'] = 0

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                          1            9
# 1              4               82                          0            4
# 2              8               51                          1            7
# 3              5               52                          1            5
# 4              7               75                          0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
performance_data['Extracurricular Activities'] = performance_data['Extracurricular Activities'].astype('int64')

# %%
performance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  int64
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(6)
# memory usage: 468.9 KB

# %%
performance_data.describe()
# Out:
#        Hours Studied  Previous Scores  Extracurricular Activities  \
# count   10000.000000     10000.000000                10000.000000
# mean        4.992900        69.445700                    0.494800
# std         2.589309        17.343152                    0.499998
# min         1.000000        40.000000                    0.000000
# 25%         3.000000        54.000000                    0.000000
# 50%         5.000000        69.000000                    0.000000
# 75%         7.000000        85.000000                    1.000000
# max         9.000000        99.000000                    1.000000
#
#         Sleep Hours  Sample Question Papers Practiced  Performance Index
# count  10000.000000                      10000.000000       10000.000000
# mean       6.530600                          4.583300          55.224800
# std        1.695863                          2.867348          19.212558
# min        4.000000                          0.000000          10.000000
# ...

# %% [markdown]
# ### Analise rapida

# %%
g2 = sns.PairGrid(performance_data)
g2.map_diag(plt.hist)
g2.map_upper(plt.scatter)
g2.map_lower(sns.lineplot)

# %% [markdown]
# ### Salvando tabela

# %% [markdown]
# #### Salvando alterações feitas até aqui

# %%
performance_data.to_csv("..\\assets\\data\\performance_data_converted.csv", index=False)

# %% [markdown]
# ### Criação de Faixas

# %%
performance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  int64
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(6)
# memory usage: 468.9 KB

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %% [markdown]
# #### Performance Index

# %%
bins = [0, 50, 80, 100]
labels = [1,2,3]
performance_data['Performance Index Faixa'] = pd.cut(performance_data['Performance Index'], bins=bins, labels=labels, right=False)
df = performance_data

# %%
df['Sample Question Papers Practiced Faixa'] = pd.cut(performance_data['Sample Question Papers Practiced'], bins=bins, labels=labels, right=False)
df['Hours Studied Faixa'] = pd.cut(performance_data['Hours Studied'], bins=bins, labels=labels, right=False)
df['Extracurricular Activities Faixa'] = pd.cut(performance_data['Extracurricular Activities'], bins=bins, labels=labels, right=False)
df['Sleep Hours Faixa'] = pd.cut(performance_data['Sleep Hours'], bins=bins, labels=labels, right=False)

# %%
df.head()
# Out:
#   Performance Index Faixa Sample Question Papers Practiced Faixa  \
# 0                       1                                      1
# 1                       1                                      1
# 2                       1                                      1
# 3                       1                                      1
# 4                       1                                      1
#
#   Hours Studied Faixa Extracurricular Activities Faixa Sleep Hours Faixa
# 0                   1                                1                 1
# 1                   1                                1                 1
# 2                   1                                1                 1
# 3                   1                                1                 1
# 4                   1                                1                 1

# %%
sns.histplot(performance_data['Performance Index'])
# Out:
# <Axes: xlabel='Performance Index', ylabel='Count'>

# %%
g3 = sns.PairGrid(performance_data)
g3.map_diag(plt.hist)
g3.map_upper(plt.scatter)
g3.map_lower(sns.lineplot)

# %% [markdown]
# ##### Salvando

# %%
df.to_csv("..\\assets\\data\\df.csv", index=False)

# %% [markdown]
# #### Previous Scores

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index Performance Index Faixa
# 0                                 1                  5                       1
# 1                                 2                  4                       1
# 2                                 2                  3                       1
# 3                                 2                  2                       1
# 4                                 5                  4                       1

# %%
sns.histplot(performance_data['Performance Index Faixa'])
# Out:
# <Axes: xlabel='Performance Index Faixa', ylabel='Count'>

# %% [markdown]
# #### Hours Studied

# %%
tempo_estudo = {1:1, 2:1, 3:2, 4:2, 5:3, 6:3, 7:4, 8:4, 9:5}
performance_data['Hours Studied'] = performance_data['Hours Studied'].map(tempo_estudo)

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              4               99                           1            9
# 1              2               82                           0            4
# 2              4               51                           1            7
# 3              3               52                           1            5
# 4              4               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index Performance Index Faixa
# 0                                 1                  5                       1
# 1                                 2                  4                       1
# 2                                 2                  3                       1
# 3                                 2                  2                       1
# 4                                 5                  4                       1

# %%
sns.histplot(performance_data['Hours Studied'])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %% [markdown]
# #### Sleep Hours

# %%
faixas_sono = {4:1, 5:2, 6:3, 7:4, 8:5, 9:5}
performance_data['Sleep Hours'] = performance_data['Sleep Hours'].map(faixas_sono)

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              4               99                           1            5
# 1              2               82                           0            1
# 2              4               51                           1            4
# 3              3               52                           1            2
# 4              4               75                           0            5
#
#    Sample Question Papers Practiced  Performance Index Performance Index Faixa
# 0                                 1                  5                       1
# 1                                 2                  4                       1
# 2                                 2                  3                       1
# 3                                 2                  2                       1
# 4                                 5                  4                       1

# %%
sns.histplot(performance_data['Sleep Hours'])
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Count'>

# %% [markdown]
# #### Sample Question Papers Practiced

# %%
question_papers = {0:1, 1:1, 2:2, 3:2, 4:3, 5:3, 6:4, 7:4, 8:5, 9:5}
performance_data['Sample Question Papers Practiced'] = performance_data['Sample Question Papers Practiced'].map(question_papers)

# %%
performance_data.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              4               99                           1            5
# 1              2               82                           0            1
# 2              4               51                           1            4
# 3              3               52                           1            2
# 4              4               75                           0            5
#
#    Sample Question Papers Practiced  Performance Index Performance Index Faixa
# 0                                 1                  5                       1
# 1                                 2                  4                       1
# 2                                 2                  3                       1
# 3                                 2                  2                       1
# 4                                 3                  4                       1

# %%
sns.histplot(performance_data['Sample Question Papers Practiced'])
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Count'>

# %% [markdown]
# #### Infografico e salvando

# %%
g4 = sns.PairGrid(performance_data)
g4.map_diag(plt.hist)
g4.map_upper(plt.scatter)
g4.map_lower(sns.lineplot)

# %%
performance_data.to_csv("..\\assets\\data\\performance_data_convertido_por_faixas.csv", index=False)

# %% [markdown]
# ### Retirada de colunas

# %%
performance_data.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index',
#        'Performance Index Faixa'],
#       dtype='object')

# %%
performance_data =performance_data.drop(['Previous Scores'], axis=1)

# %%
performance_data.columns
# Out:
# Index(['Hours Studied', 'Extracurricular Activities', 'Sleep Hours',
#        'Sample Question Papers Practiced', 'Performance Index',
#        'Performance Index Faixa'],
#       dtype='object')

# %%
performance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Extracurricular Activities        10000 non-null  int64
#  2   Sleep Hours                       10000 non-null  int64
#  3   Sample Question Papers Practiced  10000 non-null  int64
#  4   Performance Index                 10000 non-null  int64
#  5   Performance Index Faixa           10000 non-null  category
# dtypes: category(1), int64(5)
# memory usage: 400.6 KB

# %%
performance_data.to_csv("..\\assets\\data\\performance_data_convertido_por_faixas_sem_Previous.csv", index=False)
