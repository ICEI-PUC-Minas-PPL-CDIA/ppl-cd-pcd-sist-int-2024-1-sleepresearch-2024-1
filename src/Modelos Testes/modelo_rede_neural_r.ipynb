# %% [markdown]
# >   Importa as bibliotecas necessárias

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# %% [markdown]
# >   Ler os arquivos CSV em Dataframes do Pandas

# %%
df_performance = pd.read_csv('/home/rhudson/Documentos/PUC/Projeto em ciência de dados I/ppl-cd-pcd-sist-int-2024-1-sleepresearch-2024-1/assets/data/Student Stress Factors.csv')  # Ler o arquivo CSV de desempenho dos alunos
df_stress = pd.read_csv('/home/rhudson/Documentos/PUC/Projeto em ciência de dados I/ppl-cd-pcd-sist-int-2024-1-sleepresearch-2024-1/assets/data/Student_Performance.csv')  # Ler o arquivo CSV dos fatores de estresse dos alunos

# %% [markdown]
# >   Cria uma nova coluna `Student ID` no `df_performance`, atribuindo um ID inteiro único para cada aluno (de 1 a 10000)

# %%
df_performance['Student ID'] = range(1, len(df_performance) + 1)

# %% [markdown]
# >   Randomiza 520 linhas do `df_performance` e armazena em `df_performance_sample`.

# %%
df_performance_sample = df_performance.sample(n=520, random_state=1)

# %% [markdown]
# >   Combina `df_performance_sample` com `df_stress` com base no índice.

# %%
df_combined = pd.merge(df_performance_sample, df_stress, left_index=True, right_index=True)

# %% [markdown]
# >   Filtra o dataframe combinado `df_combined` para manter apenas as colunas `Sleep Hours`, `Sleep Quality` e `Performance Index`.

# %%
df_combined = df_combined[['Sleep Hours', 'Sleep Quality', 'Performance Index']]

# %% [markdown]
# >   Separa os recursos (X) e a variável alvo (y) do `df_combined`

# %%
X = df_combined.drop('Performance Index', axis=1)
y = df_combined['Performance Index']

# %% [markdown]
# >   Divide os dados em conjuntos de treinamento e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# >   Normaliza os recursos usando MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# >   Constrói, compila e treina um modelo de rede neural sequencial

# %%
model = Sequential()
model.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))  # Camada de entrada
model.add(Dense(64, activation='relu'))  # Camada oculta
model.add(Dense(1, activation='linear'))  # Camada de saída
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3586.4133 - mean_absolute_error: 56.4656 - val_loss: 3497.7183 - val_mean_absolute_error: 55.3542
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3448.0955 - mean_absolute_error: 55.4256 - val_loss: 3490.8950 - val_mean_absolute_error: 55.2919
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3391.6494 - mean_absolute_error: 55.0300 - val_loss: 3483.5881 - val_mean_absolute_error: 55.2250
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3415.3713 - mean_absolute_error: 55.1545 - val_loss: 3475.6506 - val_mean_absolute_error: 55.1524
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3279.2576 - mean_absolute_error: 54.1978 - val_loss: 3466.6487 - val_mean_absolute_error: 55.0699
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3470.8447 - mean_absolute_error: 55.3235 - val_loss: 3456.4294 - val_mean_absolute_error: 54.9760
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3201.7695 - mean_absolute_error: 53.2529 - val_loss: 3445.1267 - val_mean_absolute_error: 54.8720
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3123.7170 - mean_absolute_error: 52.3484 - val_loss: 3432.5437 - val_mean_absolute_error: 54.7559
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3323.9500 - mean_absolute_error: 54.2889 - val_loss: 3418.2500 - val_mean_absolute_error: 54.6237
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3116.6121 - mean_absolute_error: 52.2988 - val_loss: 3402.4070 - val_mean_absolute_error: 54.4767
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3227.5945 - mean_absolute_error: 53.3174 - val_loss: 3384.7881 - val_mean_absolute_error: 54.3125
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3187.0969 - mean_absolute_error: 52.8494 - val_loss: 3364.6975 - val_mean_absolute_error: 54.1243
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3289.0891 - mean_absolute_error: 53.9780 - val_loss: 3342.0085 - val_mean_absolute_error: 53.9106
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3254.7065 - mean_absolute_error: 53.4396 - val_loss: 3315.3293 - val_mean_absolute_error: 53.6579
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3329.2715 - mean_absolute_error: 54.1569 - val_loss: 3283.0442 - val_mean_absolute_error: 53.3503
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3178.1697 - mean_absolute_error: 52.8467 - val_loss: 3243.9995 - val_mean_absolute_error: 52.9760
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3145.3054 - mean_absolute_error: 52.6184 - val_loss: 3195.9604 - val_mean_absolute_error: 52.5110
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3070.1038 - mean_absolute_error: 52.1318 - val_loss: 3134.7368 - val_mean_absolute_error: 51.9126
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3048.0598 - mean_absolute_error: 51.6831 - val_loss: 3062.8350 - val_mean_absolute_error: 51.2028
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2793.3125 - mean_absolute_error: 49.2178 - val_loss: 2983.2507 - val_mean_absolute_error: 50.4045
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3009.0532 - mean_absolute_error: 51.1177 - val_loss: 2894.1799 - val_mean_absolute_error: 49.4945
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2758.3037 - mean_absolute_error: 48.5701 - val_loss: 2798.0898 - val_mean_absolute_error: 48.4918
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2765.2764 - mean_absolute_error: 48.9850 - val_loss: 2695.2830 - val_mean_absolute_error: 47.3932
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2658.8352 - mean_absolute_error: 47.6412 - val_loss: 2585.1499 - val_mean_absolute_error: 46.1869
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2466.6821 - mean_absolute_error: 45.2824 - val_loss: 2469.7864 - val_mean_absolute_error: 44.8875
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2260.9041 - mean_absolute_error: 43.0205 - val_loss: 2348.5942 - val_mean_absolute_error: 43.4786
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2225.1924 - mean_absolute_error: 42.8416 - val_loss: 2222.7339 - val_mean_absolute_error: 41.9612
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1991.7365 - mean_absolute_error: 40.5828 - val_loss: 2096.8269 - val_mean_absolute_error: 40.3896
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1974.7269 - mean_absolute_error: 39.7869 - val_loss: 1967.8646 - val_mean_absolute_error: 38.7634
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1843.5109 - mean_absolute_error: 38.4287 - val_loss: 1838.7821 - val_mean_absolute_error: 37.1082
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1823.6552 - mean_absolute_error: 38.1916 - val_loss: 1711.4591 - val_mean_absolute_error: 35.4564
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1661.5447 - mean_absolute_error: 35.5795 - val_loss: 1588.3876 - val_mean_absolute_error: 33.9400
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1493.4474 - mean_absolute_error: 33.4724 - val_loss: 1468.7299 - val_mean_absolute_error: 32.4889
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1311.5194 - mean_absolute_error: 30.7736 - val_loss: 1355.7477 - val_mean_absolute_error: 31.0592
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1291.9062 - mean_absolute_error: 30.6300 - val_loss: 1249.4419 - val_mean_absolute_error: 29.6661
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1097.9769 - mean_absolute_error: 27.8839 - val_loss: 1151.4462 - val_mean_absolute_error: 28.2816
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 981.9908 - mean_absolute_error: 25.9004 - val_loss: 1063.1593 - val_mean_absolute_error: 27.0863
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 965.8350 - mean_absolute_error: 25.5066 - val_loss: 982.5311 - val_mean_absolute_error: 26.0004
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 837.1080 - mean_absolute_error: 23.4263 - val_loss: 914.1905 - val_mean_absolute_error: 25.1551
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 747.4083 - mean_absolute_error: 22.1888 - val_loss: 854.9992 - val_mean_absolute_error: 24.4515
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 708.4119 - mean_absolute_error: 21.1410 - val_loss: 804.3958 - val_mean_absolute_error: 23.8408
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 661.1159 - mean_absolute_error: 20.5624 - val_loss: 762.1199 - val_mean_absolute_error: 23.2928
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 662.1832 - mean_absolute_error: 21.2093 - val_loss: 727.8273 - val_mean_absolute_error: 22.8862
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 636.6124 - mean_absolute_error: 20.6128 - val_loss: 701.0328 - val_mean_absolute_error: 22.5576
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 513.7465 - mean_absolute_error: 17.7035 - val_loss: 681.6992 - val_mean_absolute_error: 22.3367
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 583.7450 - mean_absolute_error: 19.5025 - val_loss: 665.7618 - val_mean_absolute_error: 22.1226
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 525.5371 - mean_absolute_error: 18.0764 - val_loss: 653.7648 - val_mean_absolute_error: 21.9460
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 504.2803 - mean_absolute_error: 18.3589 - val_loss: 645.0311 - val_mean_absolute_error: 21.8307
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 526.8337 - mean_absolute_error: 18.3740 - val_loss: 637.8575 - val_mean_absolute_error: 21.7208
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 518.3303 - mean_absolute_error: 18.0801 - val_loss: 632.8845 - val_mean_absolute_error: 21.6316
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 523.1151 - mean_absolute_error: 18.7029 - val_loss: 628.4711 - val_mean_absolute_error: 21.5393
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 488.1435 - mean_absolute_error: 17.1808 - val_loss: 625.0378 - val_mean_absolute_error: 21.4568
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 522.9365 - mean_absolute_error: 18.4235 - val_loss: 622.3679 - val_mean_absolute_error: 21.3925
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 468.0118 - mean_absolute_error: 17.4898 - val_loss: 620.0823 - val_mean_absolute_error: 21.3478
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 537.4749 - mean_absolute_error: 18.8196 - val_loss: 617.6996 - val_mean_absolute_error: 21.2973
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 516.3676 - mean_absolute_error: 18.1816 - val_loss: 615.5239 - val_mean_absolute_error: 21.2467
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 492.6109 - mean_absolute_error: 17.7056 - val_loss: 613.3796 - val_mean_absolute_error: 21.2064
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 473.8477 - mean_absolute_error: 17.5676 - val_loss: 611.3989 - val_mean_absolute_error: 21.1536
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 524.0447 - mean_absolute_error: 18.5829 - val_loss: 609.3314 - val_mean_absolute_error: 21.1151
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 475.4709 - mean_absolute_error: 17.5355 - val_loss: 607.4100 - val_mean_absolute_error: 21.0724
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 467.9764 - mean_absolute_error: 17.3569 - val_loss: 605.4785 - val_mean_absolute_error: 21.0300
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 500.8365 - mean_absolute_error: 17.9850 - val_loss: 603.3818 - val_mean_absolute_error: 21.0000
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 498.6415 - mean_absolute_error: 17.9901 - val_loss: 601.4982 - val_mean_absolute_error: 20.9607
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 444.7502 - mean_absolute_error: 16.9754 - val_loss: 599.5409 - val_mean_absolute_error: 20.9283
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 501.2377 - mean_absolute_error: 18.1673 - val_loss: 597.5877 - val_mean_absolute_error: 20.8957
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 464.2559 - mean_absolute_error: 17.3425 - val_loss: 595.6857 - val_mean_absolute_error: 20.8547
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 447.3593 - mean_absolute_error: 17.1544 - val_loss: 593.5900 - val_mean_absolute_error: 20.8313
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 496.3257 - mean_absolute_error: 17.9032 - val_loss: 591.4783 - val_mean_absolute_error: 20.8039
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 466.9695 - mean_absolute_error: 17.5038 - val_loss: 589.6617 - val_mean_absolute_error: 20.7630
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 476.4477 - mean_absolute_error: 17.5826 - val_loss: 587.7430 - val_mean_absolute_error: 20.7286
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 498.1168 - mean_absolute_error: 18.0163 - val_loss: 585.7729 - val_mean_absolute_error: 20.6989
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 443.2119 - mean_absolute_error: 16.9245 - val_loss: 584.0427 - val_mean_absolute_error: 20.6555
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 455.8910 - mean_absolute_error: 17.2597 - val_loss: 582.1725 - val_mean_absolute_error: 20.6231
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 451.4095 - mean_absolute_error: 17.0196 - val_loss: 580.2950 - val_mean_absolute_error: 20.6011
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 426.6472 - mean_absolute_error: 16.4152 - val_loss: 578.5734 - val_mean_absolute_error: 20.5597
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 523.1560 - mean_absolute_error: 18.4110 - val_loss: 576.6528 - val_mean_absolute_error: 20.5324
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 468.0826 - mean_absolute_error: 17.4423 - val_loss: 574.9393 - val_mean_absolute_error: 20.5000
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 441.0081 - mean_absolute_error: 17.0724 - val_loss: 573.0434 - val_mean_absolute_error: 20.4747
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 454.9283 - mean_absolute_error: 17.2472 - val_loss: 571.2315 - val_mean_absolute_error: 20.4488
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 446.1187 - mean_absolute_error: 17.0954 - val_loss: 569.4844 - val_mean_absolute_error: 20.4228
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 474.1902 - mean_absolute_error: 17.5547 - val_loss: 567.7335 - val_mean_absolute_error: 20.3913
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 431.5117 - mean_absolute_error: 16.3964 - val_loss: 566.2144 - val_mean_absolute_error: 20.3586
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 467.9640 - mean_absolute_error: 17.5537 - val_loss: 564.4388 - val_mean_absolute_error: 20.3369
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 474.7375 - mean_absolute_error: 17.8076 - val_loss: 562.6926 - val_mean_absolute_error: 20.3128
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 439.6876 - mean_absolute_error: 16.7472 - val_loss: 561.0172 - val_mean_absolute_error: 20.2811
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 437.3488 - mean_absolute_error: 16.7487 - val_loss: 559.4963 - val_mean_absolute_error: 20.2490
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 479.8265 - mean_absolute_error: 17.6122 - val_loss: 557.8024 - val_mean_absolute_error: 20.2214
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 486.4857 - mean_absolute_error: 17.9549 - val_loss: 556.1201 - val_mean_absolute_error: 20.2012
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 451.5255 - mean_absolute_error: 17.1218 - val_loss: 554.4310 - val_mean_absolute_error: 20.1796
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 472.3325 - mean_absolute_error: 17.6251 - val_loss: 552.8530 - val_mean_absolute_error: 20.1466
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 484.1883 - mean_absolute_error: 17.8827 - val_loss: 551.3817 - val_mean_absolute_error: 20.1140
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 426.5297 - mean_absolute_error: 16.8519 - val_loss: 549.7983 - val_mean_absolute_error: 20.0911
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 425.2317 - mean_absolute_error: 16.4136 - val_loss: 548.2452 - val_mean_absolute_error: 20.0663
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 417.8356 - mean_absolute_error: 16.4875 - val_loss: 546.8920 - val_mean_absolute_error: 20.0425
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 425.5852 - mean_absolute_error: 16.7311 - val_loss: 545.2539 - val_mean_absolute_error: 20.0111
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 473.2349 - mean_absolute_error: 17.7756 - val_loss: 543.7412 - val_mean_absolute_error: 19.9845
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 404.6622 - mean_absolute_error: 16.4751 - val_loss: 542.3886 - val_mean_absolute_error: 19.9550
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 443.2198 - mean_absolute_error: 17.1608 - val_loss: 540.8113 - val_mean_absolute_error: 19.9296
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 421.0510 - mean_absolute_error: 16.6759 - val_loss: 539.2917 - val_mean_absolute_error: 19.9044
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 404.1922 - mean_absolute_error: 16.1239 - val_loss: 537.8668 - val_mean_absolute_error: 19.8795

# %% [markdown]
# >   Prevê no conjunto de teste e calcula o erro médio absoluto

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# >   Imprime o MAE

# %%
print(f'Erro Médio Absoluto no Conjunto de Teste: {mae:.2f}')
# Out:
# Erro Médio Absoluto no Conjunto de Teste: 17.88

# %%
# O modelo parece ser pior que ruim :/
from sklearn.metrics import r2_score

# Calcula o R²
r2 = r2_score(y_test, y_pred)

# Imprime o R²
print(f'Coeficiente de Determinação (R²) no Conjunto de Teste: {r2:.2f}')

# Plotar gráfico de dispersão
plt.scatter(y_test, y_pred)
plt.title('Gráfico de Dispersão das Previsões vs. Valores Reais')
plt.xlabel('Valores Reais')
plt.ylabel('Previsões')
plt.show()
# Out:
# Coeficiente de Determinação (R²) no Conjunto de Teste: -0.23

# %% [markdown]
# >   Gráfico da perda durante o treinamento

# %%
# Plota a perda (loss) e outras métricas
plt.plot(history.history['loss'], label='Perda (Loss) de Treinamento')
plt.plot(history.history['val_loss'], label='Perda (Loss) de Validação')
plt.plot(history.history['mean_absolute_error'], label='Erro Médio Absoluto (MAE) de Treinamento')
plt.plot(history.history['val_mean_absolute_error'], label='Erro Médio Absoluto (MAE) de Validação')
plt.title('Métricas de Treinamento do Modelo')
plt.xlabel('Épocas')
plt.ylabel('Métricas')
plt.legend()
plt.show()
